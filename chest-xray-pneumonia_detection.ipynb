# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import keras

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/inceptionv3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/.DS_Store
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/.DS_Store
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0251-0001.jpeg
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0330-0001.jpeg
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0029-0001.jpeg
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0199-0001.jpeg
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0302-0001.jpeg
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0069-0001.jpeg
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0281-0001.jpeg
# ...

# %%
# count number of files in each subdirectory of a directory
def subdirectory_file_count(master_directory):
    subdirectories = os.listdir(master_directory)
    subdirectory_count = len(subdirectories)

    subdirectory_names = []
    subdirectory_file_counts = []

    for subdirectory in subdirectories:
        if not subdirectory.startswith('.'): 
            current_directory = os.path.join(master_directory, subdirectory)
            file_count = len(os.listdir(current_directory))
            subdirectory_names.append(subdirectory)
            subdirectory_file_counts.append(file_count)
    
    return subdirectory_names, subdirectory_file_counts

# %%
# We have all the train and test data inside /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/

base_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/'
train_dir = base_dir + 'train'
validation_dir = base_dir + 'val'
test_dir = base_dir + 'test'

train_classes, train_samples = subdirectory_file_count(train_dir)
val_classes, val_samples = subdirectory_file_count(validation_dir)
test_classes, test_samples = subdirectory_file_count(test_dir)

# %%
# Lets print the samples under each folder

for i in range( 0, len(train_classes)):
    print("For class-",  train_classes[i], " available samples for training:", train_samples[i])
for i in range( 0, len(val_classes)):
    print("For class-",  val_classes[i], " available samples for validation:", val_samples[i])
for i in range( 0, len(test_classes)):
    print("For class-",  test_classes[i], " available samples for testing:", test_samples[i])
# Out:
# For class- NORMAL  available samples for training: 1342
# For class- PNEUMONIA  available samples for training: 3876
# For class- NORMAL  available samples for validation: 9
# For class- PNEUMONIA  available samples for validation: 9
# For class- NORMAL  available samples for testing: 234
# For class- PNEUMONIA  available samples for testing: 390

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Lets plot the available sample distribution

dirs = ['train', 'val', 'test']
normal = [train_samples[0], val_samples[0], test_samples[0]]
pneumonia = [train_samples[1], val_samples[1], test_samples[1]]


fig, ax = plt.subplots()

rects1 = ax.bar(np.arange(len(dirs)) - 0.35/2, normal, 0.35, label='Normal')
rects2 = ax.bar(np.arange(len(dirs)) + 0.35/2, pneumonia, 0.35, label='PNEUMONIA')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Available Samples')
ax.set_title('Available Samples distribution')
ax.set_xticks(np.arange(len(dirs)))
ax.set_xticklabels(dirs)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
# Lets display the sample image of each class from train samples.

def display_images(directory, classes, images_per_class = 3):
    #images = []
    fig=plt.figure(figsize=(15, 12)) 
    imgs = 1
    for cl in classes:
        #images.append(cl)
        files = [x for x in os.listdir(os.path.join(directory, cl)) if not x.startswith('.')]
        #for filename in os.listdir(os.path.join(directory, cl)):
        for fileidx in range(0, images_per_class):
            img = mpimg.imread(os.path.join(os.path.join(directory, cl), files[fileidx]))
            if img is not None:
                #images.append(img)
                ax = fig.add_subplot(3.5, 3.5, imgs)
                ax.set_title(cl)
                plt.imshow(img)
                imgs += 1
            #if imgs > 4:
            #    continue
                
    #fig=plt.figure(figsize=(10, 15)) 
    #for i in range(1, len(images) +1):
    #    img = images[i]
    #    fig.add_subplot(5, 5, i)
    #    plt.imshow(img)
    plt.show()

    
# Display the images by passing folder path and classes    
display_images(train_dir, train_classes)

# %%
# Now we will be creating  datagenerators which would be reading images from folders

from keras.preprocessing.image import ImageDataGenerator

rescale = 1./255
target_size = (150, 150)
batch_size = 163
class_mode = "categorical"


def dir_file_count(directory):
    return sum([len(files) for r, d, files in os.walk(directory)])

train_datagen = ImageDataGenerator(
    rescale=rescale,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    class_mode=class_mode,
    batch_size=batch_size,
    shuffle=True)


validation_datagen = ImageDataGenerator(rescale=rescale)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=target_size,
    class_mode=class_mode,
    batch_size=dir_file_count(validation_dir),
    shuffle = False)


test_datagen = ImageDataGenerator(rescale=rescale)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=target_size,
    class_mode=class_mode,
    batch_size=dir_file_count(test_dir),
    shuffle = False)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
import keras
from keras.models import Sequential
from keras.applications.inception_v3 import InceptionV3
from keras import optimizers

# %%
# Now create the model.
# We will resue pretrained inception v3 model.

incep_v3 = InceptionV3(weights=None, include_top=False, input_shape=(150, 150, 3))

keras_models_dir = "../input/inceptionv3"
incep_v3.load_weights('%s/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5' % keras_models_dir)

#incep_v3 = InceptionV3(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
incep_v3.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 74, 74, 32)   864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 74, 74, 32)   96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 74, 74, 32)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# add a global spatial average pooling layer
x = incep_v3.output
x = keras.layers.Flatten()(x)
#output = BatchNormalization()(x)
#x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.5)(x)
# let's add a fully-connected layer
x = keras.layers.Dense(1024, activation='relu')(x)

# and a logistic layer -- let's say we have 2 classes
predictions = keras.layers.Dense(2, activation='softmax')(x)

# this is the model we will train
model = keras.Model(inputs=incep_v3.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in incep_v3.layers:
    layer.trainable = False

#for layer in model.layers:
#    layer.trainable = True
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 74, 74, 32)   864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 74, 74, 32)   96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 74, 74, 32)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# ...

# %%
optimizer=optimizers.Adam()
loss='categorical_crossentropy'
metrics=['accuracy']
epochs = 10

steps_per_epoch=len(train_generator)
validation_steps=len(validation_generator)


model.compile(optimizer, loss=loss, metrics=metrics)
model.fit_generator(
    train_generator,
    steps_per_epoch = steps_per_epoch,
    epochs=epochs,
    verbose=1,
    validation_data=validation_generator,
    validation_steps=validation_steps)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 213s 7s/step - loss: 1.7327 - accuracy: 0.7870 - val_loss: 2.1528 - val_accuracy: 0.5000
# Epoch 2/10
# 32/32 [==============================] - 186s 6s/step - loss: 0.2317 - accuracy: 0.9068 - val_loss: 1.9795 - val_accuracy: 0.5625
# Epoch 3/10
# 32/32 [==============================] - 187s 6s/step - loss: 0.2024 - accuracy: 0.9162 - val_loss: 1.7603 - val_accuracy: 0.5625
# Epoch 4/10
# 32/32 [==============================] - 187s 6s/step - loss: 0.1952 - accuracy: 0.9250 - val_loss: 3.2304 - val_accuracy: 0.5000
# Epoch 5/10
# 32/32 [==============================] - 187s 6s/step - loss: 0.1874 - accuracy: 0.9275 - val_loss: 1.9018 - val_accuracy: 0.5625
# Epoch 6/10
# 32/32 [==============================] - 189s 6s/step - loss: 0.1765 - accuracy: 0.9325 - val_loss: 3.3674 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
# Testing the model

print("results")
result  = model.evaluate_generator(test_generator, steps=len(test_generator), verbose=1)

print("%s%.2f  "% ("Loss     : ", result[0]))
print("%s%.2f%s"% ("Accuracy : ", result[1]*100, "%"))
# Out:
# results
# 1/1 [==============================] - 32s 32s/step
# Loss     : 1.71
# Accuracy : 67.15%

# %%
# We will try showing test images with actual class and predicted class
# As we have declared earlier, there is just one batch for test
batches_test = len(test_generator)

y_img_batch, y_true_batch = test_generator[batches_test - 1] 
y_true_batch = y_true_batch.argmax(axis=-1)

y_pred_batch = model.predict(y_img_batch)
y_pred_batch = y_pred_batch.argmax(axis=-1)


sizeofbatch = len(y_true_batch)
#print("%s%d"%     ("Batch Size : ", len(y_pred_batch)))
#print("%s%.2f%s"% ("Accuracy : ", np.mean(y_true==y_pred)*100, "%"))

# %%
class_map = {v: k for k, v in test_generator.class_indices.items()}
for j in range(601, 605):
    fig=plt.figure(figsize=(15, 12))
    ax = fig.add_subplot(3, 3, j-600)
    original = class_map[y_true_batch[j]]
    predicted = class_map[y_pred_batch[j]]
    ax.set_title(("Original:", original, "\n", "Predicted:", predicted))
    plt.imshow(y_img_batch[j])
plt.show()
